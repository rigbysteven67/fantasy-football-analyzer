# %%
#import dependencies
import requests
import pandas as pd

# SQL Alchemy
from sqlalchemy import create_engine, event

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# Config variables
from config import remote_db_user, remote_db_pwd, remote_db_endpoint, remote_db_port, remote_db_name

# %%
# read in csv as df
super_bowl_df = pd.read_csv('superbowl.csv')
super_bowl_df
# Out:
#            Date            SB                Winner  Winner Pts  \
# 0    Feb 2 2020      LIV (54)    Kansas City Chiefs          31
# 1    Feb 3 2019     LIII (53)  New England Patriots          13
# 2    Feb 4 2018      LII (52)   Philadelphia Eagles          41
# 3    Feb 5 2017       LI (51)  New England Patriots          34
# 4    Feb 7 2016            50        Denver Broncos          24
# 5    Feb 1 2015     XLIX (49)  New England Patriots          28
# 6    Feb 2 2014   XLVIII (48)      Seattle Seahawks          43
# 7    Feb 3 2013    XLVII (47)      Baltimore Ravens          34
# 8    Feb 5 2012     XLVI (46)       New York Giants          21
# 9    Feb 6 2011      XLV (45)     Green Bay Packers          31
# 10   Feb 7 2010     XLIV (44)    New Orleans Saints          31
# 11   Feb 1 2009    XLIII (43)   Pittsburgh Steelers          27
# 12   Feb 3 2008     XLII (42)       New York Giants          17
# 13   Feb 4 2007      XLI (41)    Indianapolis Colts          29
# ...

# %%
super_bowl_df.dtypes
# Out:
# Date          object
# SB            object
# Winner        object
# Winner Pts     int64
# Loser         object
# Loser Pts      int64
# MVP           object
# Stadium       object
# City          object
# State         object
# dtype: object

# %%
super_bowl_df['Year'] = super_bowl_df['Date'].str[-4:]
super_bowl_df
# Out:
#            Date            SB                Winner  Winner Pts  \
# 0    Feb 2 2020      LIV (54)    Kansas City Chiefs          31
# 1    Feb 3 2019     LIII (53)  New England Patriots          13
# 2    Feb 4 2018      LII (52)   Philadelphia Eagles          41
# 3    Feb 5 2017       LI (51)  New England Patriots          34
# 4    Feb 7 2016            50        Denver Broncos          24
# 5    Feb 1 2015     XLIX (49)  New England Patriots          28
# 6    Feb 2 2014   XLVIII (48)      Seattle Seahawks          43
# 7    Feb 3 2013    XLVII (47)      Baltimore Ravens          34
# 8    Feb 5 2012     XLVI (46)       New York Giants          21
# 9    Feb 6 2011      XLV (45)     Green Bay Packers          31
# 10   Feb 7 2010     XLIV (44)    New Orleans Saints          31
# 11   Feb 1 2009    XLIII (43)   Pittsburgh Steelers          27
# 12   Feb 3 2008     XLII (42)       New York Giants          17
# 13   Feb 4 2007      XLI (41)    Indianapolis Colts          29
# ...

# %%
super_bowl_df.drop(columns = ["Date"], inplace = True)
super_bowl_df
# Out:
#               SB                Winner  Winner Pts                 Loser  \
# 0       LIV (54)    Kansas City Chiefs          31   San Francisco 49ers
# 1      LIII (53)  New England Patriots          13      Los Angeles Rams
# 2       LII (52)   Philadelphia Eagles          41  New England Patriots
# 3        LI (51)  New England Patriots          34       Atlanta Falcons
# 4             50        Denver Broncos          24     Carolina Panthers
# 5      XLIX (49)  New England Patriots          28      Seattle Seahawks
# 6    XLVIII (48)      Seattle Seahawks          43        Denver Broncos
# 7     XLVII (47)      Baltimore Ravens          34   San Francisco 49ers
# 8      XLVI (46)       New York Giants          21  New England Patriots
# 9       XLV (45)     Green Bay Packers          31   Pittsburgh Steelers
# 10     XLIV (44)    New Orleans Saints          31    Indianapolis Colts
# 11    XLIII (43)   Pittsburgh Steelers          27     Arizona Cardinals
# ...

# %%
SB_final_df = super_bowl_df.reindex(columns = ['Year', 'SB', 'Winner', 'Winner Pts', 'Loser', 'Loser Pts', 'MVP', 'Stadium',
       'City', 'State'])
SB_final_df
# Out:
#     Year            SB                Winner  Winner Pts  \
# 0   2020      LIV (54)    Kansas City Chiefs          31
# 1   2019     LIII (53)  New England Patriots          13
# 2   2018      LII (52)   Philadelphia Eagles          41
# 3   2017       LI (51)  New England Patriots          34
# 4   2016            50        Denver Broncos          24
# 5   2015     XLIX (49)  New England Patriots          28
# 6   2014   XLVIII (48)      Seattle Seahawks          43
# 7   2013    XLVII (47)      Baltimore Ravens          34
# 8   2012     XLVI (46)       New York Giants          21
# 9   2011      XLV (45)     Green Bay Packers          31
# 10  2010     XLIV (44)    New Orleans Saints          31
# 11  2009    XLIII (43)   Pittsburgh Steelers          27
# 12  2008     XLII (42)       New York Giants          17
# 13  2007      XLI (41)    Indianapolis Colts          29
# 14  2006       XL (40)   Pittsburgh Steelers          21
# ...

# %%
# Create Engine and Pass in MySQL Connection

# Remote MySQL DB Connection  
remote_engine = create_engine(f"mysql://{remote_db_user}:{remote_db_pwd}@{remote_db_endpoint}:{remote_db_port}")
#print(f"postgresql://{local_db_user}:{local_db_pwd}@{local_db_endpoint}:{local_db_port}")

# Create a local database engine connection
remote_conn = remote_engine.connect()

# Create remote database
try:
    remote_conn.execution_options(isolation_level="AUTOCOMMIT").execute(f"CREATE DATABASE {remote_db_name}")
except Exception as e:
    print(e)

# Connect to remote database
try:
    remote_engine = create_engine(f"mysql://{remote_db_user}:{remote_db_pwd}@{remote_db_endpoint}:{remote_db_port}/{remote_db_name}")
    remote_conn = remote_engine.connect()
except Exception as e:
    print(e)  
    
#confirm tables
remote_engine.table_names()
# Out:
# (pymysql.err.ProgrammingError) (1007, "Can't create database 'fantasy_project'; database exists")
# [SQL: CREATE DATABASE fantasy_project]
# (Background on this error at: http://sqlalche.me/e/13/f405)
# ['fantasy_stats']

# %%
#upload dataframe to database
SB_final_df.to_sql(name='super_bowl_table', if_exists='append', con=remote_conn, index=False)
remote_engine.table_names()
# Out:
# ['fantasy_stats', 'super_bowl_table']

# %%
SB_final_df.to_excel('superbowl_table.xlsx')

# %%
SB_final_df.to_csv('superbowl_table.csv')
